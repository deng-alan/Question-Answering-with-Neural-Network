# %%
import glob
import os
import cPickle as pickle
from IPython.display import clear_output
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read all the tables
table_path = '../data/WikiTableQuestions/csv/'

def clean_text(s):
    return s.lower().replace('\\n', ' ').replace('\n', '')
    
def read_table(filename, path=table_path, delimiter='\t'):
    ''' given the path and file name of certain table, 
        return a dictionary with {head-title: [elements]} 
    '''
    result = {}
    with open(path+filename, 'r') as f:
        heads, head_index = f.readline().split(delimiter), []
        for head in heads:
            head = clean_text(head)
            result[head] = []
            head_index.append(head)
        
        for line in f:
            for head, ele in zip(head_index, line.split(delimiter)):
                ele = clean_text(ele)
                result[head].append(ele)
    return result

def read_all_tables(table_path=table_path):
    all_tables = {}
    for path in glob.glob(table_path+'*'):
        csv_path = path[-7:]
        for f in glob.glob(table_path+csv_path+'/*.tsv'):
            filename = f.split('/')[-1]
            context = 'csv/{0}/{1}csv'.format(csv_path, filename[:-3])
            table = read_table(csv_path + '/' + filename)
            all_tables[context] = table
    return all_tables

all_tables = read_all_tables()

# %% [raw]
# # Preprocessing, not need to re-run
# Proprocess all the questions to format:
# { 'id': {
#       'question': question (string),
#       'table_id': table_id (string),
#       'answer': answer (string),
#       'answer_position': {column name: [row indices]} # columns, row indices: might have more than one matches,
#       'syntax': {
#           index: {word, tag, pos, role, parent, [child]}
#       }
# }

# %%
def find_answer(answer, table):
    ''' return answer_position: {column name: [row indices]}
    '''
    result = {}
    for head in table:
        indices = [i for i, text in enumerate(table[head]) if text==answer.lower()]
        if len(indices)!=0:
            result[head] = indices
    return result

def process_syntax(syntax):
    result = {}
    for index, info in enumerate(syntax[1]):
        result[index] = {'word': info[0], 'tag': info[1], 'pos': info[2], 
                         'role': info[3], 'parent': None, 'children': []}
    for index, children in enumerate(syntax[2]):
        for child in children:
            result[index]['children'].append(child)
            result[child]['parent'] = index
    return result
    
def question_preprocess(loadfile, savefile):
    with open(loadfile, 'rb') as f:
        data = pickle.load(f)
    result = {}
    for info in data:
        id, question, table_id, answer, syntax = info
        answer_position = find_answer(answer, all_tables[table_id])
        syntax = process_syntax(syntax)
        result[id] = {
            'question': question,
            'table_id': table_id,
            'answer': answer,
            'answer_position': answer_position,
            'syntax': syntax
        }
    with open(savefile, 'wb') as f:
        pickle.dump(result, f)
    return result

# %%
print all_tables['csv/204-csv/249.csv']
# Out:
# {'interescting highway': ['nd\xc2\xa018\xc2\xa0\xe2\x80\x93 cavalier, larimore', 'pr\xc2\xa0243 east\xc2\xa0\xe2\x80\x93 emerson', 'pr\xc2\xa0243 west \xe2\x80\x93 blumenfeld', 'pr\xc2\xa0421 east \xe2\x80\x93 sommerfeld', 'pr\xc2\xa0201 west\xc2\xa0\xe2\x80\x93 brown, windygates, snowflake', 'pr\xc2\xa0201 east\xc2\xa0\xe2\x80\x93 letellier, dominion city, stuartburn', 'pth\xc2\xa014\xc2\xa0\xe2\x80\x93 morden, winkler, plum coulee, morris  pr\xc2\xa0332 north\xc2\xa0\xe2\x80\x93 lowe farm, brunkild, starbuck'], 'notes': ['pth 30 begins', 'begin pr 243 west concurrence', 'end pr 243 west concurrence', '', 'begin pr 201 east concurrence', 'end pr 201 east concurrence', 'pth 30 ends highway continues as pr 332'], 'municipality': ['canada-united states border', 'r.m. of rhineland', 'r.m. of rhineland', 'r.m. of rhineland', 'r.m. of rhineland', 'r.m. of rhineland', 'r.m. of rhineland'], 'location': ['canada-united states border', 'gretna', '', '', 'altona', '', 'rosenfeld'], 'km': ['0', '3', '5', '10', '14', '18', '25']}

# %%
syntaxnet = '../data/questions_syntaxnet/'
questions = '../data/PreprocessedQuestions/'
files = ['training.pkl', 'seen-tables.pkl', 'unseen-tables.pkl']
for filename in files:
    question_preprocess(syntaxnet+filename, questions+filename)

# %%
# how to load data + data schema
with open('../data/PreprocessedQuestions/training.pkl', 'rb') as f:
    data = pickle.load(f)
data[data.keys()[0]]
# Out:
# {'answer': 'Astarto',
#  'answer_position': {'title': [16]},
#  'question': 'which opera has the most acts, la fortezza al cimento or astarto?',
#  'syntax': {0: {'children': [],
#    'parent': 1,
#    'pos': 'WDT',
#    'role': 'det',
#    'tag': 'DET',
#    'word': 'which'},
#   1: {'children': [0],
#    'parent': 2,
#    'pos': 'NN',
#    'role': 'nsubj',
#    'tag': 'NOUN',
#    'word': 'opera'},
#   2: {'children': [1, 5, 13],
#    'parent': None,
#    'pos': 'VBZ',
#    'role': 'ROOT',
#    'tag': 'VERB',
#    'word': 'has'},
#   3: {'children': [],
#    'parent': 5,
#    'pos': 'DT',
#    'role': 'det',
#    'tag': 'DET',
#    'word': 'the'},
#   4: {'children': [],
#    'parent': 5,
#    'pos': 'JJS',
#    'role': 'amod',
#    'tag': 'ADJ',
#    'word': 'most'},
#   5: {'children': [3, 4, 6, 10],
#    'parent': 2,
#    'pos': 'NNS',
#    'role': 'dobj',
#    'tag': 'NOUN',
#    'word': 'acts'},
#   6: {'children': [],
#    'parent': 5,
#    'pos': ',',
#    'role': 'punct',
#    'tag': '.',
#    'word': ','},
#   7: {'children': [],
#    'parent': 10,
#    'pos': 'FW',
#    'role': 'advmod',
#    'tag': 'X',
#    'word': 'la'},
#   8: {'children': [],
#    'parent': 10,
#    'pos': 'FW',
#    'role': 'nn',
#    'tag': 'X',
#    'word': 'fortezza'},
#   9: {'children': [],
#    'parent': 10,
#    'pos': 'NNP',
#    'role': 'nn',
#    'tag': 'NOUN',
#    'word': 'al'},
#   10: {'children': [7, 8, 9, 11, 12],
#    'parent': 5,
#    'pos': 'NNP',
#    'role': 'appos',
#    'tag': 'NOUN',
#    'word': 'cimento'},
#   11: {'children': [],
#    'parent': 10,
#    'pos': 'CC',
#    'role': 'cc',
#    'tag': 'CONJ',
#    'word': 'or'},
#   12: {'children': [],
#    'parent': 10,
#    'pos': 'NN',
#    'role': 'conj',
#    'tag': 'NOUN',
#    'word': 'astarto'},
#   13: {'children': [],
#    'parent': 2,
#    'pos': '.',
#    'role': 'punct',
#    'tag': '.',
#    'word': '?'}},
#  'table_id': 'csv/204-csv/104.csv'}

# %% [markdown]
# # Task 1 - Find the correct column

# %%
# load word embedding
word_vectors = {}
with open('../glove.840B.300d.txt', 'r') as f:
    i = 0
    for line in f:
        i += 1
        if i % 100000==0: 
            clear_output()
            print 'Processing {0}th word'.format(i)
        info = line.split()
        word_vectors[info[0]] = np.array([float(x) for x in info[1:]])
# Out:
# Processing 100000th word

# %%
# find the 'W*' word, return the index
def find_w(syntax):
    for index in syntax:
        if syntax[index]['pos'][0] == 'W':
            return index
    return 0

# find the 'nearest' noun of 'W*' word
def find_answer_noun(syntax):
    w_index = find_w(syntax)
    if syntax[w_index]['pos'][0] == 'N':
        return w_index
    
    parent = syntax[w_index]['parent']
    children = syntax[w_index]['children']
    que = children
    if parent != None:
        que.append(parent)
    visited = [w_index]
    while len(que) != 0:
        index = que.pop(0)
        if index == None: continue
        if index not in visited:
            visited.append(index)
            if syntax[index]['pos'][0] == 'N':
                return index
        new_child = syntax[index]['children']
        for child in new_child:
            if child not in visited:
                que.append(child)
        new_parent = syntax[index]['parent']
        if new_parent not in visited:
            que.append(new_parent)
    
#    frontiers, visited = [w_index], {w_index}
#    while len(frontiers)!=0:
#        frontier = frontiers.pop()
#        nodes = syntax[frontier]['children']
#        for node in nodes:
#            if syntax[node]['pos'][0] == 'N':
#                return node
#            if node not in visited:
#                frontiers.insert(0, node)
#                visited.add(node)
    return 0

# for different 'W*' word, given the object key word
def find_object_word(syntax):
    w_index = find_w(syntax)
    w_word = syntax[w_index]['word']
    if w_word == 'when': return 'year'
    if w_word == 'who': return 'name'
    if w_word == 'where': return 'location'
    #if w_word == 'how':
    #    words = ['many', 'much']
    #    if syntax[w_index+1]['word'] in words: return 'number'
    index = find_answer_noun(syntax)
    return syntax[index]['word']

# %%
def cosine_similarity(w1, w2, word_vectors=word_vectors):
    w1, w2 = w1.lower().split(), w2.lower().split()
    dist = 0.0
    for ww1 in w1:
        if ww1 not in word_vectors: continue
        for ww2 in w2:
            if ww1 == ww2: return 1.0
            if ww2 not in word_vectors: continue
            v1, v2 = word_vectors[ww1], word_vectors[ww2]
            product = np.dot(v1,v2)
            length = np.sqrt(np.dot(v1,v1)*np.dot(v2,v2))
            if length == 0: return 1.0
            dist = max(dist, product/length)                
    return dist

def distance_similarity(w1, w2, word_vectors=word_vectors):
    w1, w2 = w1.lower(), w2.lower()
    if w1==w2: return float('inf')
    if w1 not in word_vectors or w2 not in word_vectors:
        return 0.0
    v1, v2 = word_vectors[w1], word_vectors[w2]
    return 1.0/max(0.01, np.sqrt(np.sum((v1-v2)**2)))

# %%
def rank_head_answer_noun_similarity(question, similarity_function = cosine_similarity):
    syntax = question['syntax']
    answer_noun = find_object_word(syntax)
    if question['answer_position'] == {}:
        return (-1, None, answer_noun)
    head = question['answer_position'].keys()[0]
    similarity = similarity_function(answer_noun, head)
    
    result = (-1, None, answer_noun)
    for h in all_tables[question['table_id']].keys():
        sim = similarity_function(answer_noun, h)
        if sim >= similarity: 
            result = (result[0]+1, h, answer_noun)
    if result[1].lower()==head.lower():
        result = (0, head, answer_noun)
    #w_index = find_w(syntax)
    #w_word = syntax[w_index]['word']
    #print w_word, result
    return result

def rank_distribution(questions):
    return [(id, rank_head_answer_noun_similarity(question)) for id, question in questions.items()]

# %%
with open('../data/PreprocessedQuestions/training.pkl', 'rb') as f:
    data = pickle.load(f)
dist = rank_distribution(data)

# %%
# Brief Analysis 
with open('../data/PreprocessedQuestions/training.pkl', 'rb') as f:
    data = pickle.load(f)
dist = rank_distribution(data)
x = [a[1][0] for a in dist]
_ = plt.hist(x, bins=max(x)-min(x))

# %%
questions_path = '../data/PreprocessedQuestions/'
files = ['training.pkl', 'seen-tables.pkl', 'unseen-tables.pkl']
column_rank = {}
for filename in files:
    with open(questions_path+filename, 'rb') as f:
        data = pickle.load(f)
    dist = rank_distribution(data)
    
    column_rank[filename[:-4]] = dist
    
    x = [a[1][0] for a in dist]
    
    count_nouns = 0
    count_ans = 0
    
    for number in x:
        if number == -1:
            count_nouns += 1
        else:
            count_ans += 1
    
    print 'We could correctly find {0:.1f}% of clolumns in {1}.'.format(100*float(sum(np.array(x)==0))/count_ans, filename[:-4])
    print '\t', sum(np.array(x)==-1), sum(np.array(x)==0), sum(np.array(x)>-1)
    print
# Out:
# We could correctly find 60.5% of clolumns in training.
# 	5464 5255 8688
#
# We could correctly find 60.4% of clolumns in seen-tables.
# 	1395 1294 2142
#
# We could correctly find 60.4% of clolumns in unseen-tables.
# 	1676 1611 2668

# %%
# The questions that get wrong columns
def str_question_with_wrong_columns(question, result):
    if result[0]==0:
        return None
    if result[0]==-1:
        return None
    return 'Answer Column: {0}, Predict Column: {1}, Rank: {2}'.format(
        question['answer_position'].keys()[0], result[1], result[0]+1)

def debug(filename):
    with open(questions_path+filename, 'rb') as f:
        data = pickle.load(f)
    print filename[:-4], ':'

    w_list = ['who', 'when', 'what', 'where', 'how', 'why']
    w_dict = {'who':0, 'when':0, 'what':0, 'where':0, 'how':0, 'why':0, 'other':0}
    w_dict_wrong = {'who':0, 'when':0, 'what':0, 'where':0, 'how':0, 'why':0, 'other':0}
    
    for id, result in column_rank[filename[:-4]]:
        question = data[id]
        debug_str = str_question_with_wrong_columns(question, result)
        w_word = question['syntax'][0]['word']
            
        if result[0] == 0:
            if w_word in w_list:
                w_dict[w_word]+=1
            else:
                w_dict['other']+=1
        if debug_str is not None and w_word == 'how':
            if w_word in w_list:
                w_dict_wrong[w_word]+=1
            else:
                w_dict_wrong['other']+=1
            #print ' Question id: ' + id
            print ' \tAnswer Noun: ' + result[2]
            print ' \t' + debug_str
            print ' \t' + question['question']
            print
    print w_dict, w_dict_wrong

# %%
filename = 'training.pkl'
debug(filename)
# Out:
# training :
#  	Answer Noun: years
#  	Answer Column: gb, Predict Column: postseason, Rank: 11
#  	how many years have the brewers competed in the nl?
#
#  	Answer Noun: competitors
#  	Answer Column: rank, Predict Column: result, Rank: 2
#  	how many competitors had less than 13.00 points?
#
#  	Answer Noun: countries
#  	Answer Column: gold, Predict Column: total, Rank: 4
#  	how many countries have at least 2 bronze medals?
#
#  	Answer Noun: albums
#  	Answer Column: #, Predict Column: title, Rank: 5
#  	how many albums did not have a time length?
#
#  	Answer Noun: forwards
#  	Answer Column: #, Predict Column: class, Rank: 8
#  	how many total forwards are on the team?
#
#  	Answer Noun: senators
#  	Answer Column: district, Predict Column: district office, Rank: 4
#  	how many louisiana state senators are democrats?
#
#  	Answer Noun: wrestlers
#  	Answer Column: entered, Predict Column: wrestler, Rank: 3
#  	how many wrestlers had a time of 6:47?
#
#  	Answer Noun: countries
#  	Answer Column: gold, Predict Column: total, Rank: 4
#  	how many countries in this competition had more than two silver medals?
#
#  	Answer Noun: people
#  	Answer Column: rank, Predict Column: result, Rank: 5
#  	how many people were ranked?
#
#  	Answer Noun: angle
#  	Answer Column: separation (au), Predict Column: semi-major axis (arcseconds), Rank: 4
#  	how many have a most recent position angle of at least 200?
#
#  	Answer Noun: years
#  	Answer Column: w, Predict Column: year, Rank: 6
#  	how many years did cooney checkaye coach the muncie flyers?
#
#  	Answer Noun: players
#  	Answer Column: rank, Predict Column: player, Rank: 2
#  	how many players transferred after 2010?
#
#  	Answer Noun: games
#  	Answer Column: #, Predict Column: pts, Rank: 7
#  	how many home games did toronto play?
#
#  	Answer Noun: nations
#  	Answer Column: gold, Predict Column: nation, Rank: 2
#  	how many nations only took one medal?
#
#  	Answer Noun: players
#  	Answer Column: place, Predict Column: money ($), Rank: 4
#  	how many players received a score below 283?
#
#  	Answer Noun: brands
#  	Answer Column: , Predict Column: therapeutic area, Rank: 5
#  	how many brands are for the dermatology area?
#
#  	Answer Noun: provinces
#  	Answer Column: map #, Predict Column: population, Rank: 6
#  	how many provinces have the same number of districts as kabul?
#
#  	Answer Noun: picks
#  	Answer Column: rd, Predict Column: pick, Rank: 5
#  	how many draft picks were between frank tripucka and dale armstrong?
#
#  	Answer Noun: song
#  	Answer Column: length, Predict Column: title, Rank: 2
#  	how long is the shortest song on the album?
#
#  	Answer Noun: italians
#  	Answer Column: bib, Predict Column: total, Rank: 5
#  	how many italians finished in the top ten?
#
#  	Answer Noun: goals
#  	Answer Column: total, Predict Column: league, Rank: 4
#  	how many goals did ismail isa score this season?
#
#  	Answer Noun: teams
#  	Answer Column: position, Predict Column: goals for, Rank: 9
#  	how many teams had less than 10 wins?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: game site, Rank: 3
#  	how many games did the broncos win in 1998 by more than 10 points?
#
#  	Answer Noun: counties
#  	Answer Column: rank, Predict Column: population, Rank: 7
#  	how many counties have a median household income of at least $50,000?
#
#  	Answer Noun: cyclists
#  	Answer Column: rank, Predict Column: speed, Rank: 5
#  	how many cyclists finished with the speed of at least 47.000?
#
#  	Answer Noun: cyclist
#  	Answer Column: rank, Predict Column: team, Rank: 4
#  	how many cyclist are not listed with a country team?
#
#  	Answer Noun: teams
#  	Answer Column: winners, Predict Column: team, Rank: 2
#  	how many teams have been winners at least 5 times?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 6
#  	how many have won at least 2 gold medals?
#
#  	Answer Noun: times
#  	Answer Column: podiums, Predict Column: points, Rank: 9
#  	how many times was the position listed as 1st?
#
#  	Answer Noun: guests
#  	Answer Column: #, Predict Column: featured guest(s), Rank: 3
#  	how many featured guests are there in total?
#
#  	Answer Noun: medals
#  	Answer Column: silver, Predict Column: bronze, Rank: 3
#  	how many more silver medals did russian win than denmark?
#
#  	Answer Noun: games
#  	Answer Column: #, Predict Column: pts, Rank: 7
#  	how many games total were played?
#
#  	Answer Noun: medals
#  	Answer Column: rank, Predict Column: bronze, Rank: 4
#  	how many more medals did egypt win than ivory coast?
#
#  	Answer Noun: medals
#  	Answer Column: rank, Predict Column: bronze, Rank: 4
#  	how many medals overall did puerto rico win?
#
#  	Answer Noun: people
#  	Answer Column: finishers, Predict Column: year, Rank: 5
#  	how many people finished the 1997 budapest half marathon?
#
#  	Answer Noun: stadiums
#  	Answer Column: #, Predict Column: stadium, Rank: 6
#  	how many stadiums have a capacity of more than 70,000?
#
#  	Answer Noun: republicans
#  	Answer Column: district, Predict Column: caucus, Rank: 6
#  	how many republicans were elected after 2000?
#
#  	Answer Noun: seats
#  	Answer Column: fourth duma, Predict Column: third duma, Rank: 5
#  	how many total seats were taken in the fourth duma?
#
#  	Answer Noun: districts
#  	Answer Column: name, Predict Column: position, Rank: 6
#  	which alumni in the 1990's has the least number of international caps?
#
#  	Answer Noun: matches
#  	Answer Column: scored, Predict Column: opponent, Rank: 5
#  	how many matches were in may 2010?
#
#  	Answer Noun: point
#  	Answer Column: no., Predict Column: team, Rank: 8
#  	how many point is tony kanaan
#
#  	Answer Noun: municipalities
#  	Answer Column: pba team, Predict Column: college, Rank: 3
#  	which team got more players, pop cola or gordon's?
#
#  	Answer Noun: teams
#  	Answer Column: wins, Predict Column: goals for, Rank: 4
#  	how many teams are there in total?
#
#  	Answer Noun: players
#  	Answer Column: pick #, Predict Column: nfl team, Rank: 3
#  	how many players from wisconsin were picked in the first round?
#
#  	Answer Noun: countries
#  	Answer Column: gold, Predict Column: total, Rank: 4
#  	how many countries earned at lest one bronze medal?
#
#  	Answer Noun: players
#  	Answer Column: rd, Predict Column: pick, Rank: 5
#  	how many players were from notre dame?
#
#  	Answer Noun: times
#  	Answer Column: times:, Predict Column: notes:, Rank: 5
#  	how many times has ricky landell held the wsl title?
#
#  	Answer Noun: teams
#  	Answer Column: rank, Predict Column: team, Rank: 5
#  	how many teams had at least five players?
#
#  	Answer Noun: drivers
#  	Answer Column: season, Predict Column: network, Rank: 2
#  	in what year was the last season of cbs's play-by-play?
#
#  	Answer Noun: wins
#  	Answer Column: week, Predict Column: opponent, Rank: 2
#  	how many wins did the chiefs have in the 1974 season?
#
#  	Answer Noun: medals
#  	Answer Column: occasion #, Predict Column: bronze, Rank: 4
#  	how many gold medals have been won by racers from japan?
#
#  	Answer Noun: weeks
#  	Answer Column: international caps, Predict Column: position, Rank: 5
#  	how many notable alumni in the 1990's are not from australia?
#
#  	Answer Noun: stations
#  	Answer Column: rf, Predict Column: network, Rank: 5
#  	how many of these missouri tv stations are actually licensed in a city in illinois (il)?
#
#  	Answer Noun: song
#  	Answer Column: time, Predict Column: title, Rank: 3
#  	how long is the song "i love you jesus?"
#
#  	Answer Noun: nations
#  	Answer Column: gold, Predict Column: nation, Rank: 2
#  	how many nations earned no bronze medals?
#
#  	Answer Noun: defendants
#  	Answer Column: title, Predict Column: peak chart positions aus, Rank: 5
#  	what's the next single after "wide open road"?
#
#  	Answer Noun: races
#  	Answer Column: rd., Predict Column: grand prix, Rank: 9
#  	how many consecutive races in a row was ayrton senna the winning driver?
#
#  	Answer Noun: commissioners
#  	Answer Column: no., Predict Column: notable for, Rank: 6
#  	how many commissioners of food and drugs did george w bush appoint?
#
#  	Answer Noun: teams
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many teams played on february 14th, 1976?
#
#  	Answer Noun: golfers
#  	Answer Column: place, Predict Column: country, Rank: 4
#  	how many golfers shot at least 2 under par at the 2010 us open?
#
#  	Answer Noun: cintron
#  	Answer Column: years until mandatory retirement, Predict Column: appointed by, Rank: 6
#  	how long did roberto feliberti cintron serve before retirement?
#
#  	Answer Noun: schools
#  	Answer Column: p.s. #, Predict Column: year closed, Rank: 7
#  	how many schools are vacant?
#
#  	Answer Noun: athletes
#  	Answer Column: bib, Predict Column: time, Rank: 6
#  	how many athletes are not ranked?
#
#  	Answer Noun: cities
#  	Answer Column: rank, Predict Column: passengers, Rank: 5
#  	how many cities from canada are on this list?
#
#  	Answer Noun: games
#  	Answer Column: m, Predict Column: opponent, Rank: 9
#  	how many games did the club play in the month of july?
#
#  	Answer Noun: riders
#  	Answer Column: points, Predict Column: rider, Rank: 2
#  	how many riders in the top 15 were riding a honda?
#
#  	Answer Noun: players
#  	Answer Column: soproni liga, Predict Column: total, Rank: 9
#  	how many players scored more than 10 goals?
#
#  	Answer Noun: ministers
#  	Answer Column: #, Predict Column: total time in office, Rank: 9
#  	how many prime ministers were born before 1850?
#
#  	Answer Noun: seasons
#  	Answer Column: other goals, Predict Column: fa cup goals, Rank: 8
#  	how many seasons did kevin gall play for yeovil town?
#
#  	Answer Noun: drivers
#  	Answer Column: no., Predict Column: manufacturer, Rank: 8
#  	how many drivers did not have a top ten position?
#
#  	Answer Noun: medals
#  	Answer Column: rank, Predict Column: bronze, Rank: 4
#  	how many bronze medals were won by the nation with the fewest gold medals?
#
#  	Answer Noun: temples
#  	Answer Column: no., Predict Column: temple, Rank: 4
#  	how many temples are listed in the table?
#
#  	Answer Noun: riders
#  	Answer Column: points, Predict Column: rider, Rank: 2
#  	how many riders were faster than massimo ottobre?
#
#  	Answer Noun: seasons
#  	Answer Column: tier, Predict Column: division, Rank: 3
#  	how many seasons did someone get 3rd place?
#
#  	Answer Noun: wins
#  	Answer Column: position, Predict Column: points, Rank: 7
#  	how many wins were there in seasons with less than 400 points?
#
#  	Answer Noun: years
#  	Answer Column: political rights, Predict Column: year, Rank: 4
#  	how many years was ali saibou president?
#
#  	Answer Noun: times
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many times were goals scored in the friendly competition?
#
#  	Answer Noun: games
#  	Answer Column: m, Predict Column: opponent, Rank: 9
#  	how many games were attended by at least 8,000 people?
#
#  	Answer Noun: athletes
#  	Answer Column: heat, Predict Column: nationality, Rank: 3
#  	how many athletes have a time of 13.29?
#
#  	Answer Noun: events
#  	Answer Column: number, Predict Column: event, Rank: 2
#  	how many events does john describe?
#
#  	Answer Noun: athletes
#  	Answer Column: rank, Predict Column: time, Rank: 3
#  	how many athletes took more than 8 minutes to run complete the race?
#
#  	Answer Noun: people
#  	Answer Column: attendance, Predict Column: result, Rank: 3
#  	how many people came to the home opener?
#
#  	Answer Noun: song
#  	Answer Column: length, Predict Column: title, Rank: 3
#  	how long is the song "likwit"?
#
#  	Answer Noun: times
#  	Answer Column: division, Predict Column: year, Rank: 7
#  	how many times did the usl a-league reach the quarterfinals?
#
#  	Answer Noun: swimmers
#  	Answer Column: rank, Predict Column: swimmer, Rank: 4
#  	how many mexican swimmers ranked in the top 10?
#
#  	Answer Noun: seasons
#  	Answer Column: passes defended, Predict Column: longest interception return, Rank: 16
#  	how many seasons had combined tackles of 70 or more?
#
#  	Answer Noun: years
#  	Answer Column: series, Predict Column: year, Rank: 3
#  	how many years did heartbeat series run in total?
#
#  	Answer Noun: years
#  	Answer Column: start, Predict Column: retired, Rank: 3
#  	how many consecutive years did parnelli place in the top 5?
#
#  	Answer Noun: times
#  	Answer Column: no, Predict Column: date, Rank: 2
#  	how many times did ricky stenhouse, jr. win before 10-03-2008?
#
#  	Answer Noun: wins
#  	Answer Column: game, Predict Column: opponent, Rank: 4
#  	how many wins did the team have before march 4,2005?
#
#  	Answer Noun: jurisdictions
#  	Answer Column: bishops, Predict Column: parishes, Rank: 3
#  	how many jurisdictions are listed in the chart?
#
#  	Answer Noun: artists
#  	Answer Column: draw, Predict Column: artist, Rank: 3
#  	how many artists scored at least 40 points?
#
#  	Answer Noun: albums
#  	Answer Column: week, Predict Column: album title, Rank: 5
#  	how many different albums does the song "i see fire" appear on?
#
#  	Answer Noun: players
#  	Answer Column: #, Predict Column: position, Rank: 5
#  	how many players have a height of at least 1.90?
#
#  	Answer Noun: nations
#  	Answer Column: lane, Predict Column: nationality, Rank: 6
#  	how many nations participated?
#
#  	Answer Noun: teams
#  	Answer Column: matches, Predict Column: goals, Rank: 5
#  	how many teams had above 20 matches in the season?
#
#  	Answer Noun: swimmers
#  	Answer Column: lane, Predict Column: time, Rank: 2
#  	how many swimmers finished in less than 1:55?
#
#  	Answer Noun: swimmers
#  	Answer Column: builder, Predict Column: length, Rank: 3
#  	did american car company or w.l. holman car company build cars that were 44' in length?
#
#  	Answer Noun: players
#  	Answer Column: #, Predict Column: size, Rank: 7
#  	how many players have german as their nationality?
#
#  	Answer Noun: times
#  	Answer Column: name, Predict Column: topics, Rank: 3
#  	which was china's first publication?
#
#  	Answer Noun: swimmers
#  	Answer Column: rank, Predict Column: time, Rank: 3
#  	how many swimmers were there from the united states in the top five in the semifinals?
#
#  	Answer Noun: games
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many games were replays?
#
#  	Answer Noun: track
#  	Answer Column: length, Predict Column: title, Rank: 2
#  	how long is the longest track on the album?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many silver medals were earned by egypt?
#
#  	Answer Noun: nations
#  	Answer Column: gold, Predict Column: nation, Rank: 2
#  	how many nations scored more total medals than brazil?
#
#  	Answer Noun: tournaments
#  	Answer Column: no., Predict Column: margin of victory, Rank: 5
#  	how many tournaments has he won by 3 or more strokes?
#
#  	Answer Noun: directors
#  	Answer Column: no., Predict Column: term of office, Rank: 4
#  	how many directors served more than 3 years?
#
#  	Answer Noun: people
#  	Answer Column: capacity, Predict Column: team, Rank: 4
#  	how many people can attend a game in holon city arena?
#
#  	Answer Noun: places
#  	Answer Column: , Predict Column: date listed, Rank: 6
#  	how many historic places are in new sharon?
#
#  	Answer Noun: version
#  	Answer Column: length, Predict Column: version, Rank: 5
#  	how long was the axwell remix version?
#
#  	Answer Noun: painters
#  	Answer Column: expression, Predict Column: drawing, Rank: 5
#  	how many painters received a mark of 14 for color?
#
#  	Answer Noun: times
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many times was the competition friendly?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many silver medals did evgeni plushenko get?
#
#  	Answer Noun: tracks
#  	Answer Column: #, Predict Column: title, Rank: 4
#  	how many tracks in word...life were produced by buckwild?
#
#  	Answer Noun: athletes
#  	Answer Column: heat, Predict Column: athlete, Rank: 4
#  	how many athletes are from russia?
#
#  	Answer Noun: schools
#  	Answer Column: outright titles, Predict Column: total finals, Rank: 6
#  	how many schools had above 5 outright titles?
#
#  	Answer Noun: staples
#  	Answer Column: plantain, Predict Column: cassava, Rank: 10
#  	how many staples have at least 1 mg of zinc?
#
#  	Answer Noun: teams
#  	Answer Column: position in 1993–94, Predict Column: team, Rank: 2
#  	how many teams are located in minsk?
#
#  	Answer Noun: athletes
#  	Answer Column: rank, Predict Column: time, Rank: 4
#  	how many athletes took at least an hour and 32 minutes?
#
#  	Answer Noun: medals
#  	Answer Column: rank, Predict Column: bronze, Rank: 4
#  	how many more gold medals did jamaica win compared to cuba?
#
#  	Answer Noun: medals
#  	Answer Column: attendance, Predict Column: record, Rank: 2
#  	what's the number of people who attended the oklahoma game on 11/29/1985?
#
#  	Answer Noun: dollars
#  	Answer Column: average receipt per visitor 2009 (usd/turista), Predict Column: tourism income  % gdp 2003, Rank: 5
#  	how many dollars on average did brazil receive per tourist in 2009?
#
#  	Answer Noun: episodes
#  	Answer Column: no., Predict Column: dub no., Rank: 5
#  	how many episodes aired originally but not in english?
#
#  	Answer Noun: dates
#  	Answer Column: issue, Predict Column: release date, Rank: 5
#  	how many release dates were in april?
#
#  	Answer Noun: teams
#  	Answer Column: laps, Predict Column: class, Rank: 3
#  	how many teams failed to finish the race after 2 laps?
#
#  	Answer Noun: students
#  	Answer Column: no., Predict Column: position, Rank: 5
#  	what is the difference, in years, between the length of eddie giacomin's career and mark messier?
#
#  	Answer Noun: times
#  	Answer Column: tier, Predict Column: division, Rank: 4
#  	how many times total did they finish first
#
#  	Answer Noun: times
#  	Answer Column: winners, Predict Column: team, Rank: 4
#  	how many total times has liverpool won?
#
#  	Answer Noun: people
#  	Answer Column: rank, Predict Column: nationality, Rank: 4
#  	how many different nationality's are on the list?
#
#  	Answer Noun: episodes
#  	Answer Column: no., Predict Column: title, Rank: 5
#  	how many episodes were directed by perry lang
#
#  	Answer Noun: interchanges
#  	Answer Column: tries, Predict Column: points, Rank: 7
#  	how many interchanges were recorded from 2000 to 2005
#
#  	Answer Noun: songs
#  	Answer Column: #, Predict Column: title, Rank: 4
#  	how many songs are longer than 3:00?
#
#  	Answer Noun: games
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many consecutive games were played in dublin in 2010?
#
#  	Answer Noun: olympics
#  	Answer Column: #, Predict Column: season, Rank: 4
#  	how many olympics has sofia akhmeteli represented georgia in the olympics?
#
#  	Answer Noun: athletes
#  	Answer Column: pos., Predict Column: date, Rank: 6
#  	how many of the athletes came from the united states?
#
#  	Answer Noun: athletes
#  	Answer Column: rank, Predict Column: time, Rank: 4
#  	how many athletes finished with the time less than 40.00?
#
#  	Answer Noun: years
#  	Answer Column: tier, Predict Column: division, Rank: 4
#  	how many years were they in tier 3
#
#  	Answer Noun: people
#  	Answer Column: population (2011 census), Predict Column: population (2007 estimation), Rank: 3
#  	how many people lived in predeal in 2011?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 5
#  	how many silver medals were won by italy?
#
#  	Answer Noun: skaters
#  	Answer Column: fp, Predict Column: placings, Rank: 7
#  	how many skaters had points greater than 2600?
#
#  	Answer Noun: wins
#  	Answer Column: week, Predict Column: opponent, Rank: 2
#  	how many wins were before their win on october 26?
#
#  	Answer Noun: prost
#  	Answer Column: rd., Predict Column: grand prix, Rank: 2
#  	how many did alain prost have the fastest lap?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many bronze medals did russia earn?
#
#  	Answer Noun: loses
#  	Answer Column: round, Predict Column: opponent, Rank: 4
#  	how many loses did virgil zwicker have?
#
#  	Answer Noun: artists
#  	Answer Column: pos., Predict Column: year, Rank: 6
#  	how many artists had sales above 900,000?
#
#  	Answer Noun: players
#  	Answer Column: goals, Predict Column: opponent, Rank: 3
#  	how many players scored at least 30 goals?
#
#  	Answer Noun: competitions
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many competitions were not friendly?
#
#  	Answer Noun: industries
#  	Answer Column: ranking, Predict Column: industry, Rank: 8
#  	how many oil and gas industries made the top 10 in ranking of revenue list?
#
#  	Answer Noun: times
#  	Answer Column: semifinalists, Predict Column: total, Rank: 9
#  	how many times has belarus been first runner-up?
#
#  	Answer Noun: u.s.
#  	Answer Column: no., Predict Column: original air date, Rank: 2
#  	how many of the episodes did not air in the u.s.?
#
#  	Answer Noun: goals
#  	Answer Column: gf, Predict Column: round, Rank: 9
#  	how many total goals have been scored against croatia in the world cup?
#
#  	Answer Noun: years
#  	Answer Column: division, Predict Column: country, Rank: 5
#  	how many consecutive years did he score more than 2 goals?
#
#  	Answer Noun: years
#  	Answer Column: , Predict Column: municipality, Rank: 5
#  	how many years are spanned from the earliest listing to the latest listing?
#
#  	Answer Noun: renovations
#  	Answer Column: rank, Predict Column: time, Rank: 4
#  	how many women from england were ranked in top 14 in the heats of 100m women's hurdles?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: game site, Rank: 3
#  	how many games went into overtimes?
#
#  	Answer Noun: drivers
#  	Answer Column: points, Predict Column: team, Rank: 6
#  	how many drivers did team rahal have in the race?
#
#  	Answer Noun: runners
#  	Answer Column: rank, Predict Column: time, Rank: 6
#  	how many runners took 2 minutes at the most to run 1500 meters?
#
#  	Answer Noun: athletes
#  	Answer Column: rank, Predict Column: time, Rank: 5
#  	how many athletes finished the race under 1:56?
#
#  	Answer Noun: players
#  	Answer Column: #, Predict Column: size, Rank: 7
#  	how many players weigh more than michael baumer?
#
#  	Answer Noun: teams
#  	Answer Column: points, Predict Column: team, Rank: 2
#  	how many different teams were represented at the 2007 steelback grand prix?
#
#  	Answer Noun: parks
#  	Answer Column: land area (km²), Predict Column: national park, Rank: 2
#  	how many national parks were established after 1990?
#
#  	Answer Noun: racers
#  	Answer Column: rank, Predict Column: time, Rank: 4
#  	how many racers finished the course in under forty seconds?
#
#  	Answer Noun: candidates
#  	Answer Column: counties, Predict Column: delegates, Rank: 5
#  	how many candidates got more than 5% of the votes?
#
#  	Answer Noun: players
#  	Answer Column: games started, Predict Column: player, Rank: 2
#  	how many players weighed more than 200 pounds?
#
#  	Answer Noun: people
#  	Answer Column: capacity, Predict Column: home team, Rank: 3
#  	how many total people can fit in windsor park?
#
#  	Answer Noun: gonzelz
#  	Answer Column: notes, Predict Column: year, Rank: 5
#  	how long did gonzelz throw for in 1983?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 5
#  	how many total medals did argentina win?
#
#  	Answer Noun: countries
#  	Answer Column: points, Predict Column: place, Rank: 6
#  	how many countries other than spain placed 2nd in the national final category?
#
#  	Answer Noun: countries
#  	Answer Column: rank, Predict Column: total, Rank: 3
#  	how many countries earned only one gold medal?
#
#  	Answer Noun: cities
#  	Answer Column: rank, Predict Column: population 1996, Rank: 8
#  	how many cities (census subdivisions) had at least half a million people in 1996?
#
#  	Answer Noun: players
#  	Answer Column: goals, Predict Column: opponent, Rank: 3
#  	how many players scored at least ten goals?
#
#  	Answer Noun: teams
#  	Answer Column: for, Predict Column: drawn, Rank: 7
#  	how many teams won less than the pune strykers?
#
#  	Answer Noun: players
#  	Answer Column: no., Predict Column: position, Rank: 6
#  	how many players are australian?
#
#  	Answer Noun: drivers
#  	Answer Column: points, Predict Column: grid, Rank: 5
#  	how many drivers from germany?
#
#  	Answer Noun: riders
#  	Answer Column: pos., Predict Column: rider, Rank: 6
#  	how many american riders were present?
#
#  	Answer Noun: players
#  	Answer Column: total, Predict Column: league, Rank: 4
#  	how many players did not score a goal in cup play?
#
#  	Answer Noun: buildings
#  	Answer Column: rank, Predict Column: height ft (m), Rank: 5
#  	how many buildings have less than 20 floors?
#
#  	Answer Noun: matches
#  	Answer Column: entered, Predict Column: time, Rank: 5
#  	how many matches lasted at least 4 minutes?
#
#  	Answer Noun: presidents
#  	Answer Column: number, Predict Column: year, Rank: 2
#  	how many club presidents held their position in the 19th century?
#
#  	Answer Noun: fcrcs
#  	Answer Column: album, Predict Column: year, Rank: 5
#  	"i'll be your fool tonight" and "in another minute" were on what album?
#
#  	Answer Noun: coaches
#  	Answer Column: wins, Predict Column: seasons, Rank: 5
#  	how many coaches had above 500 wins?
#
#  	Answer Noun: games
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many games had less than 5 total goals scored?
#
#  	Answer Noun: swimmers
#  	Answer Column: rank, Predict Column: time, Rank: 3
#  	how many swimmers swam faster than 1:03.59?
#
#  	Answer Noun: players
#  	Answer Column: pick #, Predict Column: nfl team, Rank: 3
#  	how many players are qbs?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many bronze medals does togo have?
#
#  	Answer Noun: athletes
#  	Answer Column: lane, Predict Column: time, Rank: 4
#  	how many athletes finished before pinki pramanik?
#
#  	Answer Noun: districts
#  	Answer Column: postal code, Predict Column: population, Rank: 5
#  	how many districts have a population density of at lest 1000.0?
#
#  	Answer Noun: hits
#  	Answer Column: peak chart positions us country, Predict Column: year, Rank: 3
#  	how many #1 hits did kitty well have?
#
#  	Answer Noun: race
#  	Answer Column: fin, Predict Column: laps, Rank: 9
#  	how many race car drivers out of the 43 listed drove toyotas?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many more medals did india earn compared to pakistan?
#
#  	Answer Noun: districts
#  	Answer Column: map #, Predict Column: population, Rank: 6
#  	how many districts are in the province of kunduz?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many total medals did norway win?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: results final score, Rank: 4
#  	how many games had more than 18,000 people?
#
#  	Answer Noun: cyclist
#  	Answer Column: rank, Predict Column: team, Rank: 4
#  	how many cyclist do not have -1 laps down?
#
#  	Answer Noun: games
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many consecutive games did enfield and leyton orient play in the first round proper?
#
#  	Answer Noun: teams
#  	Answer Column: grid, Predict Column: team, Rank: 5
#  	how many teams competed in the 1998 marlboro grand prix of miami?
#
#  	Answer Noun: democrats
#  	Answer Column: district, Predict Column: district office, Rank: 4
#  	how many democrats are in office?
#
#  	Answer Noun: events
#  	Answer Column: member, Predict Column: date, Rank: 5
#  	how many solar saros events lasted longer than 4 minutes?
#
#  	Answer Noun: stadiums
#  	Answer Column: #, Predict Column: stadium, Rank: 6
#  	how many stadiums are above 60,000 people?
#
#  	Answer Noun: players
#  	Answer Column: round, Predict Column: pick, Rank: 4
#  	how many players had the position of wr according to this chart?
#
#  	Answer Noun: months
#  	Answer Column: may, Predict Column: year, Rank: 3
#  	how many months had a record high of 111 degrees?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 5
#  	how many more gold medals must qatar win before they can earn 12 gold medals?
#
#  	Answer Noun: players
#  	Answer Column: fa cup, Predict Column: total, Rank: 8
#  	how many players have values from the fa cup?
#
#  	Answer Noun: episodes
#  	Answer Column: no., Predict Column: dub no., Rank: 5
#  	how many episodes of sailor moon did not have an english air date?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: game site, Rank: 3
#  	how many games started after 4:00 pm edt?
#
#  	Answer Noun: people
#  	Answer Column: attendance, Predict Column: opening general session guest(s), Rank: 8
#  	how many people were in attendance to the event in the year 2000?
#
#  	Answer Noun: tournaments
#  	Answer Column: no., Predict Column: margin of victory, Rank: 5
#  	how many total tournaments has he won?
#
#  	Answer Noun: drivers
#  	Answer Column: points, Predict Column: grid, Rank: 5
#  	how many drivers drove a ferrari in the race?
#
#  	Answer Noun: years
#  	Answer Column: position, Predict Column: points, Rank: 5
#  	how many consecutive years did modris stelle drive beginning in 2001?
#
#  	Answer Noun: races
#  	Answer Column: no, Predict Column: race, Rank: 4
#  	how many races are 100?
#
#  	Answer Noun: numbers
#  	Answer Column: #, Predict Column: home, Rank: 6
#  	how many consecutive numbers are listed?
#
#  	Answer Noun: ranks
#  	Answer Column: tournament, Predict Column: margin of victory, Rank: 3
#  	what tournament was nancy lopez's first lpga tour win?
#
#  	Answer Noun: songs
#  	Answer Column: chart positions us country, Predict Column: chart positions can country, Rank: 4
#  	how many songs were released after 1977?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many gold medals did italy receive?
#
#  	Answer Noun: medals
#  	Answer Column: rank, Predict Column: bronze, Rank: 4
#  	how many gold medals did italy, belgium and ireland have altogether.
#
#  	Answer Noun: landmarks
#  	Answer Column: , Predict Column: summary, Rank: 4
#  	how many of the landmarks are defined as bunkers?
#
#  	Answer Noun: ministers
#  	Answer Column: , Predict Column: left office, Rank: 5
#  	how many ministers were in office less than a year?
#
#  	Answer Noun: locks
#  	Answer Column: length (miles), Predict Column: year opened, Rank: 5
#  	how many more locks does caledonian canal have compared to aberdeenshire canal?
#
#  	Answer Noun: minutes
#  	Answer Column: entered, Predict Column: time, Rank: 4
#  	how many lasted at least 6 minutes?
#
#  	Answer Noun: tracks
#  	Answer Column: #, Predict Column: title, Rank: 4
#  	how many tracks last for more than three minutes?
#
#  	Answer Noun: events
#  	Answer Column: member, Predict Column: date, Rank: 5
#  	how many total events will occur in all?
#
#  	Answer Noun: difference
#  	Answer Column: , Predict Column: date listed, Rank: 6
#  	how many years difference is there between the listings for bass boarding house and ora blanchard house?
#
#  	Answer Noun: countries
#  	Answer Column: gold, Predict Column: total, Rank: 4
#  	how many countries did not earn silver medals?
#
#  	Answer Noun: brands
#  	Answer Column: , Predict Column: therapeutic area, Rank: 5
#  	how many top selling brands target dermatology?
#
#  	Answer Noun: weeks
#  	Answer Column: competition, Predict Column: event, Rank: 4
#  	what competition is lorenzo's top position in?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many more medals has slovakia wopn in comparison to germany?
#
#  	Answer Noun: images
#  	Answer Column: , Predict Column: name, Rank: 6
#  	how many images are listed?
#
#  	Answer Noun: schools
#  	Answer Column: outright titles, Predict Column: total finals, Rank: 6
#  	how many schools have had at least 3 share titles?
#
#  	Answer Noun: episodes
#  	Answer Column: ep#, Predict Column: title, Rank: 5
#  	how many episodes aired in july 1995?
#
#  	Answer Noun: teams
#  	Answer Column: place, Predict Column: team, Rank: 3
#  	how many teams have the same amount of runners-up as maccabi tel aviv?
#
#  	Answer Noun: races
#  	Answer Column: rnd, Predict Column: circuit, Rank: 7
#  	how many races were there total?
#
#  	Answer Noun: competitors
#  	Answer Column: bib, Predict Column: time, Rank: 6
#  	how many competitors did not start the race at all?
#
#  	Answer Noun: songs
#  	Answer Column: order #, Predict Column: original artist, Rank: 6
#  	how many songs was claudio zoli the original artist?
#
#  	Answer Noun: contestants
#  	Answer Column: represent, Predict Column: contestant, Rank: 3
#  	how many contestants are at least 21 years old?
#
#  	Answer Noun: drivers
#  	Answer Column: points, Predict Column: team, Rank: 6
#  	how many drivers had at least 10 points?
#
#  	Answer Noun: times
#  	Answer Column: start, Predict Column: year, Rank: 2
#  	how many times did he finish all 200 laps?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 5
#  	how many total medals did switzerland and france win?
#
#  	Answer Noun: representatives
#  	Answer Column: , Predict Column: party, Rank: 6
#  	how many representatives served before the 1800s began?
#
#  	Answer Noun: parks
#  	Answer Column: land area (km²), Predict Column: national park, Rank: 2
#  	how many parks were established after the year 2000?
#
#  	Answer Noun: times
#  	Answer Column: no. in season, Predict Column: original air date, Rank: 3
#  	how many times did shelley jensen directed episodes in season 6?
#
#  	Answer Noun: companies
#  	Answer Column: arms sales as share of company’s total sales (%),, Predict Column: 2010 arms sales (us$ m.), Rank: 7
#  	how many companies are under the united states?
#
#  	Answer Noun: players
#  	Answer Column: rank, Predict Column: player, Rank: 2
#  	how many players transferred to ajax?
#
#  	Answer Noun: albums
#  	Answer Column: peak chart positions us christian, Predict Column: peak chart positions us heatseekers, Rank: 4
#  	how many albums has this band released?
#
#  	Answer Noun: drivers
#  	Answer Column: points, Predict Column: team, Rank: 6
#  	how many drivers earned at least 20 points or more?
#
#  	Answer Noun: people
#  	Answer Column: #, Predict Column: team, Rank: 5
#  	how many people are not driving a chevrolet silverado?
#
#  	Answer Noun: saros
#  	Answer Column: duration (min:sec), Predict Column: mag., Rank: 5
#  	how long did the the saros on july 30, 2307 last for?
#
#  	Answer Noun: contestants
#  	Answer Column: represent, Predict Column: contestant, Rank: 3
#  	how many contestants are 20 years old?
#
#  	Answer Noun: years
#  	Answer Column: democratic party, Predict Column: year, Rank: 5
#  	how many years did the democratic party have the majority before 1876 in the south carolina house of representatives?
#
#  	Answer Noun: points
#  	Answer Column: wins, Predict Column: points, Rank: 4
#  	how many points did stelle get in the 2001 season?
#
#  	Answer Noun: counties
#  	Answer Column: rank, Predict Column: total, Rank: 3
#  	how many counties have at least one silver medal?
#
#  	Answer Noun: people
#  	Answer Column: 2000 attendance, Predict Column: 2010 attendance, Rank: 12
#  	how many people attended the 2000 animeiowa?
#
#  	Answer Noun: air
#  	Answer Column: #, Predict Column: air date, Rank: 8
#  	how long did the program air for in days?
#
#  	Answer Noun: victories
#  	Answer Column: no., Predict Column: result, Rank: 5
#  	how many consecutive victories included an enemy aircraft as the foe?
#
#  	Answer Noun: deputies
#  	Answer Column: senators, Predict Column: total deputies, Rank: 5
#  	how many more total deputies does benji have than state senators?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many medals did france get in total?
#
#  	Answer Noun: bearers
#  	Answer Column: #, Predict Column: season, Rank: 4
#  	how many summer flag bearers have there been?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: game site, Rank: 2
#  	how many games had an attendance of 10,000 at most?
#
#  	Answer Noun: teams
#  	Answer Column: won, Predict Column: team, Rank: 3
#  	how many teams won at least 2 games throughout the 1951 world ice hockey championships?
#
#  	Answer Noun: drivers
#  	Answer Column: points, Predict Column: team, Rank: 6
#  	how many canadian drivers finished in at least 10th position or better?
#
#  	Answer Noun: tracks
#  	Answer Column: #, Predict Column: title, Rank: 3
#  	how many tracks were produced by milanna miles and rick long?
#
#  	Answer Noun: countries
#  	Answer Column: bib, Predict Column: time, Rank: 6
#  	how many countries were represented?
#
#  	Answer Noun: drivers
#  	Answer Column: laps, Predict Column: driver, Rank: 2
#  	how many drivers ended the race early because of engine problems?
#
#  	Answer Noun: games
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many games only had one goal scored total?
#
#  	Answer Noun: districts
#  	Answer Column: postal code, Predict Column: population, Rank: 5
#  	how many districts are there in this city?
#
#  	Answer Noun: wrestlers
#  	Answer Column: #, Predict Column: days held, Rank: 7
#  	how many wrestlers are there total on the chart?
#
#  	Answer Noun: times
#  	Answer Column: starts, Predict Column: avg. start, Rank: 4
#  	how many times was his average finish below 18?
#
#  	Answer Noun: irie
#  	Answer Column: time, Predict Column: nationality, Rank: 6
#  	how long did it take ryosuke irie to finish?
#
#  	Answer Noun: networks
#  	Answer Column: affiliates, Predict Column: network name, Rank: 3
#  	how many networks does tv azteca own?
#
#  	Answer Noun: tsuchiya
#  	Answer Column: time, Predict Column: opponent, Rank: 10
#  	how long did taiki tsuchiya last?
#
#  	Answer Noun: times
#  	Answer Column: drop, Predict Column: date, Rank: 2
#  	how many times is fiji listed as the opposition?
#
#  	Answer Noun: tracks
#  	Answer Column: #, Predict Column: title, Rank: 4
#  	how many tracks in word...life have at most two songwriters?
#
#  	Answer Noun: artists
#  	Answer Column: draw, Predict Column: artist, Rank: 2
#  	how many artists scored more than 30 points?
#
#  	Answer Noun: tons
#  	Answer Column: displacement, Predict Column: speed, Rank: 4
#  	how many tons does the te-class displace?
#
#  	Answer Noun: people
#  	Answer Column: population (2006), Predict Column: population (2011), Rank: 3
#  	how many people total are there in aberdeen and alameda combined?
#
#  	Answer Noun: teams
#  	Answer Column: rank, Predict Column: team, Rank: 5
#  	how many teams have at least a time of 4:00?
#
#  	Answer Noun: times
#  	Answer Column: district, Predict Column: residence, Rank: 5
#  	how many times is the word republican on the list?
#
#  	Answer Noun: bells
#  	Answer Column: #, Predict Column: diameter (mm), Rank: 6
#  	how many bells weight less than 1000 kg?
#
#  	Answer Noun: years
#  	Answer Column: #, Predict Column: left office, Rank: 5
#  	how many total years did sir patrick duncan serve in office?
#
#  	Answer Noun: drivers
#  	Answer Column: rank, Predict Column: diver, Rank: 7
#  	how many drivers raced in the preliminary round?
#
#  	Answer Noun: racers
#  	Answer Column: laps, Predict Column: rider, Rank: 2
#  	how many racers did not use an aprilia or a honda?
#
#  	Answer Noun: volume
#  	Answer Column: pages, Predict Column: contents, Rank: 2
#  	how long, in pages, is volume 6 of doctor who classics?
#
#  	Answer Noun: staples
#  	Answer Column: plantain, Predict Column: cassava, Rank: 10
#  	how many staples have more than 5 grams of fiber?
#
#  	Answer Noun: songs
#  	Answer Column: #, Predict Column: songwriters, Rank: 5
#  	how many songs were produced by will.i.am?
#
#  	Answer Noun: riders
#  	Answer Column: pos., Predict Column: rider, Rank: 6
#  	how many riders scored at least 10 final points?
#
#  	Answer Noun: countries
#  	Answer Column: no., Predict Column: 2009 winter universiade, Rank: 8
#  	how many countries had at least 25 points?
#
#  	Answer Noun: competitions
#  	Answer Column: goal, Predict Column: competition, Rank: 2
#  	how many competitions were not friendly?
#
#  	Answer Noun: mountains
#  	Answer Column: rank, Predict Column: peak name, Rank: 5
#  	how many mountains were measured in the bd explorer in 2012?
#
#  	Answer Noun: games
#  	Answer Column: , Predict Column: opponents, Rank: 7
#  	how many games were attended by more than 1500 people?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many gold medals did india win?
#
#  	Answer Noun: racers
#  	Answer Column: rank, Predict Column: time, Rank: 2
#  	how many racers finished the race in under 8:21:00?
#
#  	Answer Noun: people
#  	Answer Column: drop, Predict Column: opposition, Rank: 2
#  	how many people that are not diego dominguez have scored at least 24 points in a match for italy?
#
#  	Answer Noun: racers
#  	Answer Column: grid, Predict Column: entrant, Rank: 3
#  	how many racers had cooper-climax as their constructor?
#
#  	Answer Noun: championships
#  	Answer Column: runner-up, Predict Column: years runner-up, Rank: 2
#  	how many championships does nippon sport science university have
#
#  	Answer Noun: weights
#  	Answer Column: #, Predict Column: size, Rank: 7
#  	how many weights are at least 90kg?
#
#  	Answer Noun: times
#  	Answer Column: division, Predict Column: year, Rank: 7
#  	how many times was the result listed as 1st under the regular season column?
#
#  	Answer Noun: opponent
#  	Answer Column: tie, Predict Column: home team, Rank: 3
#  	how may of the teams shut out their opponent in this round?
#
#  	Answer Noun: nations
#  	Answer Column: gold, Predict Column: nation, Rank: 2
#  	how many nations share the seventh rank?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 5
#  	how many total medals were given out?
#
#  	Answer Noun: houston
#  	Answer Column: player, Predict Column: college, Rank: 4
#  	how did houston pick next after david carr?
#
#  	Answer Noun: competitors
#  	Answer Column: rank, Predict Column: time, Rank: 2
#  	how many competitors were there in this race?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: score, Rank: 2
#  	how many games did the bombers win?
#
#  	Answer Noun: games
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many games did the bolton wanderers and newcastle united play before there was a definitive winner in the fifth round proper?
#
#  	Answer Noun: seasons
#  	Answer Column: division, Predict Column: goals, Rank: 5
#  	how many seasons were no goals scored?
#
#  	Answer Noun: singles
#  	Answer Column: us modern rock, Predict Column: us mainstream rock, Rank: 3
#  	how many singles reached the us mainstream rock chart?
#
#  	Answer Noun: days
#  	Answer Column: tour, Predict Column: date start, Rank: 3
#  	how many days does the japan super series last?
#
#  	Answer Noun: sites
#  	Answer Column: , Predict Column: date listed, Rank: 6
#  	how many sites were added to the list before 1970?
#
#  	Answer Noun: songs
#  	Answer Column: #, Predict Column: title, Rank: 4
#  	how many songs have kyza and skriblah as the featured guests?
#
#  	Answer Noun: scorers
#  	Answer Column: , Predict Column: pts/game, Rank: 6
#  	how many scorers from england scored above 15 points?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many gold medals where won in total?
#
#  	Answer Noun: games
#  	Answer Column: #, Predict Column: pts, Rank: 7
#  	how many games did the senators play in january?
#
#  	Answer Noun: hospitals
#  	Answer Column: rank, Predict Column: # beds, Rank: 6
#  	how many more general acute care hospitals are there in california than rehabilitation hospitals?
#
#  	Answer Noun: song
#  	Answer Column: length, Predict Column: title, Rank: 3
#  	how long is the song from the lion king?
#
#  	Answer Noun: routes
#  	Answer Column: role, Predict Column: year, Rank: 3
#  	what was this actor's first television role?
#
#  	Answer Noun: points
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many points did leicester city score?
#
#  	Answer Noun: song
#  	Answer Column: trainer, Predict Column: post, Rank: 7
#  	what is the name of the top horse's trainer?
#
#  	Answer Noun: nations
#  	Answer Column: rank, Predict Column: nation, Rank: 3
#  	how many nations earned at least ten bronze medals?
#
#  	Answer Noun: victories
#  	Answer Column: no., Predict Column: margin of victory, Rank: 5
#  	how many victories did he have in april?
#
#  	Answer Noun: reigns
#  	Answer Column: combined defenses, Predict Column: wrestler, Rank: 4
#  	how many reigns has joey ryan had?
#
#  	Answer Noun: acts
#  	Answer Column: # albums released under bad boy, Predict Column: act, Rank: 2
#  	how many acts had no albums released under bad boy?
#
#  	Answer Noun: songs
#  	Answer Column: draw, Predict Column: place, Rank: 8
#  	how many of the songs in the 2008 ogae second chance contest were in english?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many more bronze medals were awarded than silver?
#
#  	Answer Noun: releases
#  	Answer Column: #, Predict Column: collected material, Rank: 6
#  	how may releases were after the year 2009?
#
#  	Answer Noun: players
#  	Answer Column: round, Predict Column: pick, Rank: 4
#  	how many canadian players are there in the 1974 nhl amateur draft?
#
#  	Answer Noun: goals
#  	Answer Column: total goals, Predict Column: league goals, Rank: 2
#  	how many total goals did kit lawlor score from 1950 to 1954?
#
#  	Answer Noun: swimmers
#  	Answer Column: rank, Predict Column: swimmer, Rank: 4
#  	how many swimmers are from mexico?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 5
#  	how many total medals did brazil received?
#
#  	Answer Noun: athletes
#  	Answer Column: rank, Predict Column: result, Rank: 3
#  	how many athletes had a better result than tatyana bocharova?
#
#  	Answer Noun: neighborhoods
#  	Answer Column: 2012 population rank, Predict Column: population (2011), Rank: 5
#  	how many industrial neighborhoods exist in calgary?
#
#  	Answer Noun: people
#  	Answer Column: no., Predict Column: time/retired, Rank: 9
#  	how many people completed 200 laps?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many gold medals did germany earn?
#
#  	Answer Noun: songs
#  	Answer Column: #, Predict Column: title, Rank: 4
#  	how many songs are less than 4 minutes in length?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many combined silver medals did china, india, and japan earn ?
#
#  	Answer Noun: games
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many games had a score of 2-3 or 3-2?
#
#  	Answer Noun: results
#  	Answer Column: heat, Predict Column: result, Rank: 3
#  	how many of the results were not higher than the united states?
#
#  	Answer Noun: points
#  	Answer Column: , Predict Column: team, Rank: 5
#  	how many points did arnaud demare receive?
#
#  	Answer Noun: games
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many games had four total points scored or more?
#
#  	Answer Noun: landmarks
#  	Answer Column: , Predict Column: date built, Rank: 6
#  	how many landmarks are in the hannover square historic district?
#
#  	Answer Noun: games
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many games played by sunderland are listed here?
#
#  	Answer Noun: people
#  	Answer Column: attendance, Predict Column: time, Rank: 4
#  	how many people attended the game on 12/01/2013?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: game site, Rank: 2
#  	how many games had at least 10,000 people in attendance?
#
#  	Answer Noun: riders
#  	Answer Column: points, Predict Column: rider, Rank: 4
#  	how many riders used a motorcycle manufactured by honda?
#
#  	Answer Noun: songs
#  	Answer Column: global asia top 15, Predict Column: channel [v] top 20, Rank: 9
#  	how many songs were on the mtv taiwan top 20 chart?
#
#  	Answer Noun: wins
#  	Answer Column: week, Predict Column: opponent, Rank: 2
#  	how many consecutive wins took place before they lost their first time?
#
#  	Answer Noun: times
#  	Answer Column: tournaments played, Predict Column: year, Rank: 3
#  	how many times has christel boeljon had a top-10 finish in the ladies european tour?
#
#  	Answer Noun: seats
#  	Answer Column: candidates elected, Predict Column: year of election, Rank: 3
#  	how many more seats were available in 1975 than 1963?
#
#  	Answer Noun: versions
#  	Answer Column: position, Predict Column: year, Rank: 4
#  	what is peter widen's top most position ever in world indoor championships?
#
#  	Answer Noun: positions
#  	Answer Column: grid, Predict Column: team, Rank: 4
#  	how many positions are held by canada?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many medals does iraq have in total?
#
#  	Answer Noun: songs
#  	Answer Column: #, Predict Column: title, Rank: 4
#  	how many songs are at most 3 minutes long?
#
#  	Answer Noun: pos.
#  	Answer Column: tier, Predict Column: division, Rank: 5
#  	how many were in the 2nd pos.?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 5
#  	how many medals did the usa win?
#
#  	Answer Noun: games
#  	Answer Column: no, Predict Column: test no, Rank: 4
#  	how many games are listed in the table?
#
#  	Answer Noun: songs
#  	Answer Column: #, Predict Column: title, Rank: 4
# ...
#  	Answer Column: relegations, Predict Column: team, Rank: 4
#  	how many teams had the most seasons?
#
#  	Answer Noun: temples
#  	Answer Column: song, Predict Column: channel [v] top 20, Rank: 9
#  	which song has the longest weeks on global asia's top 15 chart?
#
#  	Answer Noun: songs
#  	Answer Column: televote, Predict Column: total, Rank: 7
#  	how many songs were juried about eight?
#
#  	Answer Noun: tracks
#  	Answer Column: #, Predict Column: title, Rank: 4
#  	how many tracks are in the album?
#
#  	Answer Noun: games
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many games did the home team score at least 3 goals?
#
#  	Answer Noun: circuits
#  	Answer Column: rnd, Predict Column: winning driver, Rank: 8
#  	how many circuits did were run?
#
#  	Answer Noun: companies
#  	Answer Column: ranking, Predict Column: industry, Rank: 8
#  	how many companies have at least 200 billion in revenue for oil and gas?
#
#  	Answer Noun: temples
#  	Answer Column: no., Predict Column: temple, Rank: 4
#  	how many temples are in the city of muroto?
#
#  	Answer Noun: teams
#  	Answer Column: rank, Predict Column: time, Rank: 4
#  	how many teams finished below 3 minutes and 3 seconds?
#
#  	Answer Noun: mayors
#  	Answer Column: #, Predict Column: political party, Rank: 5
#  	how many mayors were either fisherman or farmers?
#
#  	Answer Noun: players
#  	Answer Column: #, Predict Column: Σ points, Rank: 4
#  	how many players had final scores higher than 5?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: game site, Rank: 3
#  	how many consecutive games did the denver broncos win to start the 1998 season?
#
#  	Answer Noun: cars
#  	Answer Column: number, Predict Column: livery, Rank: 3
#  	how many of these cars are operational?
#
#  	Answer Noun: votes
#  	Answer Column: +/–, Predict Column: seats, Rank: 5
#  	how many votes were counted as invalid or blank votes?
#
#  	Answer Noun: years
#  	Answer Column: republican party, Predict Column: year, Rank: 5
#  	how many years did the south carolina house of representatives compose of only independence/other and no democrats or republicans?
#
#  	Answer Noun: laps
#  	Answer Column: no, Predict Column: class, Rank: 7
#  	how many finished more than 150 laps?
#
#  	Answer Noun: countries
#  	Answer Column: gold, Predict Column: total, Rank: 4
#  	how many countries have at least 10 gold medals in the asian youth games?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many gold medals did japan win?
#
#  	Answer Noun: medals
#  	Answer Column: total, Predict Column: bronze, Rank: 5
#  	how many total medals did russia win?
#
#  	Answer Noun: countries
#  	Answer Column: gold, Predict Column: total, Rank: 4
#  	how many countries scored no gold medals at this event?
#
#  	Answer Noun: times
#  	Answer Column: rank, Predict Column: total, Rank: 3
#  	how many times has chile been awarded?
#
#  	Answer Noun: matters
#  	Answer Column: #, Predict Column: sections of the constitution allowing their institution, Rank: 5
#  	how many matters have political party as their "type"?
#
#  	Answer Noun: times
#  	Answer Column: #, Predict Column: left office, Rank: 5
#  	how many times has dervi&#351; ero&#287;lu been in office?
#
#  	Answer Noun: people
#  	Answer Column: attendance, Predict Column: result, Rank: 5
#  	how many people attended the game held on november 10, 1996?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: game site, Rank: 3
#  	how many games have a winning result (w) before november 25, 2007?
#
#  	Answer Noun: drivers
#  	Answer Column: no, Predict Column: chassis, Rank: 4
#  	how many drivers use v8 engines?
#
#  	Answer Noun: games
#  	Answer Column: association, Predict Column: year, Rank: 5
#  	which association awarded jones' first award after the year 2000?
#
#  	Answer Noun: countries
#  	Answer Column: rank, Predict Column: total, Rank: 3
#  	how many countries have one more than 10 gold medals?
#
#  	Answer Noun: medals
#  	Answer Column: silver, Predict Column: bronze, Rank: 3
#  	how many silver medals did poland win?
#
#  	Answer Noun: times
#  	Answer Column: points, Predict Column: time, Rank: 2
#  	how many times was the fiat abarth 124 rallye car used?
#
#  	Answer Noun: teams
#  	Answer Column: silver, Predict Column: bronze, Rank: 6
#  	how many teams scored the same amount of gold medals as mexico?
#
#  	Answer Noun: nations
#  	Answer Column: gold, Predict Column: nation, Rank: 2
#  	how many nations have a total of 1 medal won?
#
#  	Answer Noun: nations
#  	Answer Column: notes, Predict Column: year, Rank: 4
#  	how long was huang le's longest jump in 2002?
#
#  	Answer Noun: rutgers
#  	Answer Column: favor, Predict Column: polling firm, Rank: 2
#  	how many in favor votes did rutgers eagleton give in march 2014?
#
#  	Answer Noun: games
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many consecutive games were played on october 10, 1999?
#
#  	Answer Noun: players
#  	Answer Column: 140+, Predict Column: 180s, Rank: 10
#  	how many players have a 3 dart average of more than 97?
#
#  	Answer Noun: games
#  	Answer Column: week, Predict Column: game site, Rank: 2
#  	how many games were played at the meadowlands?
#
#  	Answer Noun: popov
#  	Answer Column: race 1 time, Predict Column: event, Rank: 6
#  	how long did it take for lyubomir popov to finish the giant slalom in race 1?
#
#  	Answer Noun: streak
#  	Answer Column: week, Predict Column: opponent, Rank: 2
#  	how long was the biggest win streak?
#
#  	Answer Noun: escorts
#  	Answer Column: number, Predict Column: date, Rank: 2
#  	how many consecutive escorts were in 1943?
#
#  	Answer Noun: points
#  	Answer Column: #, Predict Column: opponent, Rank: 6
#  	how many points did the team score against panama and colombia combined?
#
#  	Answer Noun: os
#  	Answer Column: length, Predict Column: title, Rank: 2
#  	how long os the longest track on the album?
#
#  	Answer Noun: records
#  	Answer Column: #, Predict Column: date, Rank: 6
#  	how many records does australia hold for pole vaulting?
#
#  	Answer Noun: teams
#  	Answer Column: pos., Predict Column: laps, Rank: 8
#  	how many teams are in the top five positions?
#
#  	Answer Noun: place
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many took place at 2013 asian indoor-martial arts games competition?
#
#  	Answer Noun: countries
#  	Answer Column: rank, Predict Column: total, Rank: 3
#  	how many countries won more silver medals than japan?
#
#  	Answer Noun: titles
#  	Answer Column: №, Predict Column: title, Rank: 4
#  	how many titles did bob balsar direct?
#
#  	Answer Noun: golds
#  	Answer Column: total, Predict Column: bronze, Rank: 4
#  	how many more golds did russia have than germany?
#
#  	Answer Noun: swimmers
#  	Answer Column: rank, Predict Column: swimmer, Rank: 4
#  	how many swimmers had a time of at least 1:00
#
#  	Answer Noun: times
#  	Answer Column: año, Predict Column: title, Rank: 5
#  	what year was natalia oriero's first tv role?
#
#  	Answer Noun: areas
#  	Answer Column: rank, Predict Column: urban area, Rank: 7
#  	how many urban areas have a density below 2,500?
#
#  	Answer Noun: players
#  	Answer Column: n°, Predict Column: date of birth, Rank: 5
#  	how many players are older than cyril guittet?
#
#  	Answer Noun: fessel
#  	Answer Column: rank, Predict Column: bronze, Rank: 6
#  	what's the number of silver medals did chile win?
#
#  	Answer Noun: stations
#  	Answer Column: rf, Predict Column: network, Rank: 5
#  	how many television stations serve the cape girardeau area?
#
#  	Answer Noun: songs
#  	Answer Column: position, Predict Column: artist, Rank: 5
#  	how many songs had at least 500,000 sales?
#
#  	Answer Noun: players
#  	Answer Column: rank, Predict Column: player, Rank: 2
#  	how many players had a transfer fee of at least 8 million?
#
#  	Answer Noun: years
#  	Answer Column: w, Predict Column: year, Rank: 6
#  	how many years did earl ball coach the muncie flyers?
#
#  	Answer Noun: times
#  	Answer Column: #, Predict Column: opponent, Rank: 7
#  	how many times is the venue located in brazil?
#
#  	Answer Noun: feet
#  	Answer Column: township, Predict Column: population, Rank: 9
#  	what town's population density is roughly the same as pheonix township?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many gold medals did russia earn?
#
#  	Answer Noun: teams
#  	Answer Column: place, Predict Column: team, Rank: 3
#  	how many teams won at least 1 title?
#
#  	Answer Noun: episodes
#  	Answer Column: no., Predict Column: title, Rank: 5
#  	how many other episodes were written by john zinman other than "reunion"?
#
#  	Answer Noun: piotr
#  	Answer Column: notes, Predict Column: event, Rank: 6
#  	how long did it take piotr to run the medley relay in 2001?
#
#  	Answer Noun: swimmers
#  	Answer Column: lane, Predict Column: time, Rank: 2
#  	how many swimmers were from the us?
#
#  	Answer Noun: games
#  	Answer Column: peak chart positions us, Predict Column: year, Rank: 4
#  	what was her peak ranking in the us for the single "it wasn't god who made honky tonk angles"?
#
#  	Answer Noun: countries
#  	Answer Column: gold, Predict Column: total, Rank: 4
#  	how many countries won more than 3 bronze metals?
#
#  	Answer Noun: wins
#  	Answer Column: week, Predict Column: opponent, Rank: 4
#  	how many wins are there?
#
#  	Answer Noun: employers
#  	Answer Column: #, Predict Column: employer, Rank: 3
#  	how many employers listed have less than 250 employees?
#
#  	Answer Noun: times
#  	Answer Column: #, Predict Column: opponent, Rank: 9
#  	how many times was there a score of w 9-1?
#
#  	Answer Noun: attendance
#  	Answer Column: tie, Predict Column: home team, Rank: 5
#  	how many games attendance was under 1000?
#
#  	Answer Noun: times
#  	Answer Column: #, Predict Column: opponent, Rank: 6
#  	how many times was south korea the consecutive opponent?
#
#  	Answer Noun: people
#  	Answer Column: attendance, Predict Column: result, Rank: 2
#  	how many people attended the game in november against sunderland?
#
#  	Answer Noun: teams
#  	Answer Column: draw (pe), Predict Column: played (pj), Rank: 7
#  	how many teams scored at least 17 goals?
#
#  	Answer Noun: singles
#  	Answer Column: peak chart positions us, Predict Column: peak chart positions swi, Rank: 12
#  	how many singles have a ranking of 1 under ger?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many silver medals did turkey win?
#
#  	Answer Noun: countries
#  	Answer Column: rank, Predict Column: total, Rank: 3
#  	how many countries earned no bronze medals?
#
#  	Answer Noun: games
#  	Answer Column: model name, Predict Column: portable, Rank: 3
#  	what is the next model listed after disk'o?
#
#  	Answer Noun: airlines
#  	Answer Column: ranking, Predict Column: passengers, Rank: 4
#  	how many airlines have a steady ranking?
#
#  	Answer Noun: racers
#  	Answer Column: number, Predict Column: tyre, Rank: 6
#  	how many racers had an offenhauser engine?
#
#  	Answer Noun: golds
#  	Answer Column: nation, Predict Column: bronze, Rank: 6
#  	how has the most golds?
#
#  	Answer Noun: players
#  	Answer Column: #, Predict Column: position, Rank: 5
#  	how many total players are on the current roster?
#
#  	Answer Noun: players
#  	Answer Column: #, Predict Column: nationality, Rank: 5
#  	how many players were drafted?
#
#  	Answer Noun: countries
#  	Answer Column: , Predict Column: team, Rank: 5
#  	how many countries appear more than once on the chart?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many more silver medals did the united states win compared to russia?
#
#  	Answer Noun: track
#  	Answer Column: length, Predict Column: title, Rank: 2
#  	how long is the longest track listed?
#
#  	Answer Noun: songs
#  	Answer Column: #, Predict Column: title, Rank: 5
#  	how many total songs are on this album?
#
#  	Answer Noun: medals
#  	Answer Column: silver, Predict Column: bronze, Rank: 3
#  	how many gold medals did puerto rico earn?
#
#  	Answer Noun: years
#  	Answer Column: #, Predict Column: years served, Rank: 9
#  	how many years did the first three presidents serve combined?
#
#  	Answer Noun: times
#  	Answer Column: top 5, Predict Column: avg. start, Rank: 5
#  	how many times was his average start below 20?
#
#  	Answer Noun: peaks
#  	Answer Column: no, Predict Column: peak, Rank: 7
#  	how many peaks are listed in italy?
#
#  	Answer Noun: times
#  	Answer Column: fp, Predict Column: placings, Rank: 7
#  	how many times does the unites states appear in the nations column?
#
#  	Answer Noun: medals
#  	Answer Column: gold, Predict Column: bronze, Rank: 2
#  	how many european baseball championship gold medals does italy need in order to have the same total amount of any type of medal as netherlands?
#
#  	Answer Noun: songs
#  	Answer Column: singing position, Predict Column: song title, Rank: 2
#  	how many songs are on the list?
#
#  	Answer Noun: brands
#  	Answer Column: , Predict Column: therapeutic area, Rank: 5
#  	how many brands are for depression?
#
#  	Answer Noun: game
#  	Answer Column: attendance, Predict Column: opponent, Rank: 8
#  	how many attended the june 22 game?
#
#  	Answer Noun: times
#  	Answer Column: pens, Predict Column: pts, Rank: 9
#  	how many times was 24 points or more achieved by an italian player before 2000?
#
#  	Answer Noun: points
#  	Answer Column: new points, Predict Column: points defending, Rank: 4
#  	how many new points did nikolay davydenko have?
#
#  	Answer Noun: women
#  	Answer Column: fp, Predict Column: placings, Rank: 7
#  	how many women from the united states competed in the 1971 world figure skating championships?
#
#  	Answer Noun: replays
#  	Answer Column: tie no, Predict Column: home team, Rank: 4
#  	how many replays were there in the first round proper, november 1988?
#
#  	Answer Noun: compositions
#  	Answer Column: republican party, Predict Column: year, Rank: 5
#  	how many consecutive compositions did the republicans win from 1865 to 1874?
#
#  	Answer Noun: wins
#  	Answer Column: co-driver, Predict Column: difference, Rank: 5
#  	who was dabi sordo's co-driver?
#
#  	Answer Noun: participants
#  	Answer Column: draw, Predict Column: place, Rank: 3
#  	how many participants sang english language songs?
#
#  	Answer Noun: players
#  	Answer Column: appearances, Predict Column: goals, Rank: 3
#  	how many players had at least 20 league goals scored?
#
#  	Answer Noun: years
#  	Answer Column: tier, Predict Column: division, Rank: 4
#  	how many years was the team in the 3 a division?
#
#  	Answer Noun: results
#  	Answer Column: heat, Predict Column: result, Rank: 3
#  	how many results were at least 45?
#
#  	Answer Noun: riders
#  	Answer Column: points, Predict Column: rider, Rank: 2
#  	how many riders got more than 10 points?
#
#  	Answer Noun: points
#  	Answer Column: notes, Predict Column: position, Rank: 3
#  	lorraine moller's top time overall was
#
#  	Answer Noun: artists
#  	Answer Column: color, Predict Column: drawing, Rank: 4
#  	how many artists scored 0 for expression?
#
#  	Answer Noun: mayors
#  	Answer Column: #, Predict Column: political party, Rank: 5
#  	how many mayors were in office for a total of 9 years?
#
#  	Answer Noun: opponents
#  	Answer Column: week, Predict Column: opponent, Rank: 4
#  	how many opponents were played twice that season?
#
#  	Answer Noun: people
#  	Answer Column: #, Predict Column: season, Rank: 4
#  	how many total different people have born the glad for samoa at the olympics?
#
#  	Answer Noun: players
#  	Answer Column: , Predict Column: pts/game, Rank: 6
#  	how many players were from england?
#
#  	Answer Noun: ansons
#  	Answer Column: # used, Predict Column: 1968 cf designator, Rank: 6
#  	how many avro ansons were used from 1940-1947?
#
#  	Answer Noun: months
#  	Answer Column: apr, Predict Column: oct, Rank: 10
#  	how many months how a record low below 25 degrees?
#
#  	Answer Noun: motorcycles
#  	Answer Column: points, Predict Column: manufacturer, Rank: 7
#  	how many honda motorcycles completed the race?
#
#  	Answer Noun: countries
#  	Answer Column: rnd, Predict Column: circuit, Rank: 7
#  	how many countries participated at reliant park
#
#  	Answer Noun: mountains
#  	Answer Column: rank, Predict Column: height (ft), Rank: 9
#  	how many mountains have a height higher than 8,000 meters?
#
# {'what': 1667, 'who': 577, 'when': 85, 'how': 481, 'other': 2398, 'where': 47, 'why': 0} {'what': 0, 'who': 0, 'when': 0, 'how': 998, 'other': 0, 'where': 0, 'why': 0}

# %%
filename = 'seen-tables.pkl'
debug(filename)
# Out:
# seen-tables :
#  Question id: ns-1586
#  	Answer Noun: game
#  	Answer Column: date and time, Predict Column: opponent, Rank: 6
#  	when was the last game recorded in the records?
#  Question id: ns-830
#  	Answer Noun: line
#  	Answer Column: first section opened, Predict Column: last ex- tension, Rank: 7
#  	when was the earliest first line created?
#  Question id: ns-3499
#  	Answer Noun: parnelli
#  	Answer Column: year, Predict Column: retired, Rank: 9
#  	when was the next time parnelli placed in the top 5 after 1963?
#  Question id: ns-3248
#  	Answer Noun: university
#  	Answer Column: established, Predict Column: institution, Rank: 2
#  	when did the university of essex gain university status?
#  Question id: ns-380
#  	Answer Noun: 1st
#  	Answer Column: season, Predict Column: position, Rank: 5
#  	when did the team last rank 1st?
#  Question id: ns-1870
#  	Answer Noun: clagett
#  	Answer Column: first elected, Predict Column: party, Rank: 6
#  	when was galen r. clagett first elected?
#  Question id: ns-285
#  	Answer Noun: match
#  	Answer Column: date, Predict Column: opponent, Rank: 4
#  	when was the first international match won by the sahrawi national football team?
#  Question id: ns-3422
#  	Answer Noun: when
#  	Answer Column: , Predict Column: thursday, Rank: 6
#  	when is "belmonte" on?
# 8 30

# %%
filename = 'unseen-tables.pkl'
debug(filename)
# Out:
# unseen-tables :
#  Question id: nu-3978
#  	Answer Noun: bengals
#  	Answer Column: year, Predict Column: rec, Rank: 4
#  	when did the cincinnati bengals have 55 receptions?
#  Question id: nu-2136
#  	Answer Noun: departure
#  	Answer Column: departure date, Predict Column: name, Rank: 5
#  	when was the first departure?
#  Question id: nu-2419
#  	Answer Noun: year
#  	Answer Column: season, Predict Column: place, Rank: 2
#  	when was the first year to appear lower than 6th place?
#  Question id: nu-2986
#  	Answer Noun: world
#  	Answer Column: released, Predict Column: image, Rank: 2
#  	when did devo first release "beautiful world"?
#  Question id: nu-3254
#  	Answer Noun: election
#  	Answer Column: most recent election results, Predict Column: incumbent electoral history, Rank: 7
#  	when was the last election held in az?
#  Question id: nu-2442
#  	Answer Noun: competition
#  	Answer Column: year, Predict Column: event, Rank: 3
#  	when was his first competition?
#  Question id: nu-2844
#  	Answer Noun: league
#  	Answer Column: club performance season norway, Predict Column: league apps league, Rank: 9
#  	when did nevland play in the allsvenskan league?
#  Question id: nu-106
#  	Answer Noun: race
#  	Answer Column: year, Predict Column: event, Rank: 3
#  	when did leonor piuza last compete in a race?
#  Question id: nu-694
#  	Answer Noun: team
#  	Answer Column: year, Predict Column: team, Rank: 3
#  	when was the last year team penske finished first?
# 9 45
